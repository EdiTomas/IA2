# %% [markdown]
# Algoritmo de Best First. Con **heuristica de Casilla fuera de lugar**

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i

def heuristic(nodo_actual,nodo_fin):
    return [x != y for (x, y) in zip(nodo_actual, nodo_fin)].count(True)

def sucesores(n,s,ni):

   return [[n[1]+n[0]+n[2]+n[3],heuristic(n[1]+n[0]+n[2]+n[3],s),inc(),ni[3]+1],
            [n[0]+n[2]+n[1]+n[3],heuristic(n[0]+n[2]+n[1]+n[3],s),inc(),ni[3]+1],
            [n[0]+n[1]+n[3]+n[2],heuristic(n[0]+n[1]+n[3]+n[2],s),inc(),ni[3]+1]]

def bestfirst(begin,end):
    l = [[begin, heuristic(begin, end),inc(),0]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      if current[0]== end :
              dot.node(str(current[2]), str(current[0]),shape='doublecircle',fillcolor='pink',style='filled')
              print("Visited:"+str(len(visited))+" nodes \n")
              print("No visited:"+str(len(l))+" nodes \n")
              print("Nivel:"+str(current[3])+" nodes \n")
              return print("Found:"+str(i)+" nodes")
      tmp =  sucesores(current[0],end,current)
      if tmp:
              for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]),label = str(x[1]))
              l.extend(tmp)
              l.sort(key=lambda x: int(x[1]))
    print("Not Found:"+str(i)+" nodes")

dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

bestfirst("halo","hola")
#bestfirst("aloh","hola")

dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited:7 nodes
#
# No visited:12 nodes
#
# Nivel:3 nodes
#
# Found:19 nodes

# %% [markdown]
# Algoritmo de Best First. Con **heuristica de Mahanthan**

# %%
# posiciones
#  halo hola
#  0123 0321
# ahlo hlao haol
# 1023 0132 0213

from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i


def posicion(n):
  pos =[]
  for x in range(0,len(n)):
    if n[x]=="h":
      pos.append(0)
    elif n[x]=="a":
      pos.append(1)
    elif n[x]=="l":
      pos.append(2)
    elif n[x]=="o":
      pos.append(3)
  return pos

def heuristic(nodo_actual,nodo_fin):
    return  sum (abs (x - y) for (x, y) in zip(nodo_actual, nodo_fin))

def sucesores(n,s,ni):

   return [ [n[1]+n[0]+n[2]+n[3], heuristic(posicion(n[1]+n[0]+n[2]+n[3]),posicion(s)),inc(),ni[3]+1],
            [n[0]+n[2]+n[1]+n[3],heuristic(posicion(n[0]+n[2]+n[1]+n[3]),posicion(s)),inc(),ni[3]+1],
            [n[0]+n[1]+n[3]+n[2],heuristic(posicion(n[0]+n[1]+n[3]+n[2]),posicion(s)),inc(),ni[3]+1]]

def bestfirst(begin,end):
    l = [[begin, heuristic(posicion(begin),posicion(end)),inc(),0]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      if current[0]== end :
              dot.node(str(current[2]), str(current[0]),shape='doublecircle',fillcolor='pink',style='filled')
              print("Visited:"+str(len(visited))+" nodes \n")
              print("No visited:"+str(len(l))+" nodes \n")
              print("Nivel:"+str(current[3])+" nodes \n")
              return print("Found:"+str(i)+" nodes")
      tmp =  sucesores(current[0],end,current)
      #tmp.reverse()
      if tmp:
              for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]),label = str(x[1]))
              l.extend(tmp)
              l.sort(key=lambda x: int(x[1]))
    print("Not Found:"+str(i)+" nodes")

dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

bestfirst("halo","hola")

dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited:4 nodes
#
# No visited:6 nodes
#
# Nivel:3 nodes
#
# Found:10 nodes

# %% [markdown]
# Algoritmo de Beam. **Con heuristica de Mahanthan**

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i


def posicion(n):
  pos =[]
  for x in range(0,len(n)):
    if n[x]=="h":
      pos.append(0)
    elif n[x]=="a":
      pos.append(1)
    elif n[x]=="l":
      pos.append(2)
    elif n[x]=="o":
      pos.append(3)
  return pos

def heuristic(nodo_actual,nodo_fin):
    return  sum (abs (x - y) for (x, y) in zip(nodo_actual, nodo_fin))

def sucesores(n,s,ni):

   return [ [n[1]+n[0]+n[2]+n[3], heuristic(posicion(n[1]+n[0]+n[2]+n[3]),posicion(s)),inc(),ni[3]+1],
            [n[0]+n[2]+n[1]+n[3],heuristic(posicion(n[0]+n[2]+n[1]+n[3]),posicion(s)),inc(),ni[3]+1],
            [n[0]+n[1]+n[3]+n[2],heuristic(posicion(n[0]+n[1]+n[3]+n[2]),posicion(s)),inc(),ni[3]+1]]

def beam(begin,end,b):
    l = [[begin, heuristic(posicion(begin),posicion(end)),inc(),0]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      if current[0]== end :
              dot.node(str(current[2]), str(current[0]),shape='doublecircle',fillcolor='pink',style='filled')
              print("Visited:"+str(len(visited))+" nodes \n")
              print("No visited:"+str(len(l))+" nodes \n")
              print("Nivel:"+str(current[3])+" nodes \n")
              return print("Found:"+str(len(visited)+len(l))+" nodes")
      #tmp =  sucesores(current[0],end,current)
      suc =  sucesores(current[0],end,current)
      #suc.reverse()
      suc.sort(key=lambda x: int(x[1]))
      tmp = []
      for x in range(0,len(suc)):
             if x > (b-1):
                break
             tmp.append(suc[x])
      if tmp:
              for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]),label = str(x[1]))
              l.extend(tmp)
              l.sort(key=lambda x: int(x[1]))
    print("Not Found:"+str(i)+" nodes")

dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

beam("halo","hola",2)

dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited:4 nodes
#
# No visited:3 nodes
#
# Nivel:3 nodes
#
# Found:7 nodes

# %% [markdown]
# Algoritmo de Colinas con Mahathan

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i


def posicion(n):
  pos =[]
  for x in range(0,len(n)):
    if n[x]=="h":
      pos.append(0)
    elif n[x]=="a":
      pos.append(1)
    elif n[x]=="l":
      pos.append(2)
    elif n[x]=="o":
      pos.append(3)
  return pos

def heuristic(nodo_actual,nodo_fin):
    return  sum (abs (x - y) for (x, y) in zip(nodo_actual, nodo_fin))

def sucesores(n,s,ni):

   return [ [n[1]+n[0]+n[2]+n[3], heuristic(posicion(n[1]+n[0]+n[2]+n[3]),posicion(s)),inc(),ni[3]+1],
            [n[0]+n[2]+n[1]+n[3],heuristic(posicion(n[0]+n[2]+n[1]+n[3]),posicion(s)),inc(),ni[3]+1],
            [n[0]+n[1]+n[3]+n[2],heuristic(posicion(n[0]+n[1]+n[3]+n[2]),posicion(s)),inc(),ni[3]+1]]

def colinas(begin,end):
    b=1
    l = [[begin, heuristic(posicion(begin),posicion(end)),inc(),0]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      if current[0]== end :
              dot.node(str(current[2]), str(current[0]),shape='doublecircle',fillcolor='pink',style='filled')
              print("Visited:"+str(len(visited))+" nodes \n")
              print("No visited:"+str(len(l))+" nodes \n")
              print("Nivel:"+str(current[3])+" nodes \n")
              return print("Found:"+str(len(visited)+len(l))+" nodes")
      #tmp =  sucesores(current[0],end,current)
      suc =  sucesores(current[0],end,current)
      #suc.reverse()
      suc.sort(key=lambda x: int(x[1]))
      tmp = []
      for x in range(0,len(suc)):
             if x > (b-1):
                break
             tmp.append(suc[x])
      if tmp:
              for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]),label = str(x[1]))
              l.extend(tmp)
              l.sort(key=lambda x: int(x[1]))
    print("Not Found:"+str(i)+" nodes")

dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

colinas("halo","hola")

dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited:4 nodes
#
# No visited:0 nodes
#
# Nivel:3 nodes
#
# Found:4 nodes

# %% [markdown]
# Ejemplo 1
# Resolver el 4 puzzle con estado inicial 3214 y final 1234, utilizando Best First con heuristica Manhathan ¿Cuantos nodos fueron visitados?

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i

#3214 1234
#0123
def posicion(n):
  pos =[]
  for x in range(0,len(n)):
    if n[x]=="3":
      pos.append(0)
    elif n[x]=="2":
      pos.append(1)
    elif n[x]=="l":
      pos.append(2)
    elif n[x]=="4":
      pos.append(3)
  return pos

def heuristic(nodo_actual,nodo_fin):
    return  sum (abs (x - y) for (x, y) in zip(nodo_actual, nodo_fin))

def sucesores(n,s,ni):
  return [ [n[1]+n[0]+n[2]+n[3], heuristic(posicion(n[1]+n[0]+n[2]+n[3]),posicion(s)),inc(),ni[3]+1],
            [n[0]+n[2]+n[1]+n[3],heuristic(posicion(n[0]+n[2]+n[1]+n[3]),posicion(s)),inc(),ni[3]+1],
            [n[0]+n[1]+n[3]+n[2],heuristic(posicion(n[0]+n[1]+n[3]+n[2]),posicion(s)),inc(),ni[3]+1]]

def colinas(begin,end):
    b=1
    l = [[begin, heuristic(posicion(begin),posicion(end)),inc(),0]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      if current[0]== end :
              dot.node(str(current[2]), str(current[0]),shape='doublecircle',fillcolor='pink',style='filled')
              print("Visited:"+str(len(visited))+" nodes \n")
              print("No visited:"+str(len(l))+" nodes \n")
              print("Nivel:"+str(current[3])+" nodes \n")
              return print("Found:"+str(len(visited)+len(l))+" nodes")
      tmp =  sucesores(current[0],end,current)
      #suc =  sucesores(current[0],end,current)
      #suc.reverse()
      #suc.sort(key=lambda x: int(x[1]))
      #tmp = []
      #for x in range(0,len(suc)):
      #       if x > (b-1):
      #          break
      #       tmp.append(suc[x])
      if tmp:
              for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]),label = str(x[1]))
              l.extend(tmp)
              l.sort(key=lambda x: int(x[1]))
    print("Not Found:"+str(i)+" nodes")

dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')
#3214 1234
colinas("3214","1234")

dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited:5 nodes
#
# No visited:8 nodes
#
# Nivel:3 nodes
#
# Found:13 nodes

# %% [markdown]
# Ejemplo 2  Casillas fuera de lugar  Resolver un puzzle con estado inicial DCBA Y FINAL ABCD utlizando Beam de tamaño 2 con heuristica casillas fuera de lugar ¿Cual fue la heuristica maxima calculada?

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i

def heuristic(nodo_actual,nodo_fin):
    return [x != y for (x, y) in zip(nodo_actual, nodo_fin)].count(True)

def sucesores(n,s,ni):
 #DCBA
 #0123
   return [[n[1]+n[0]+n[2]+n[3],heuristic(n[1]+n[0]+n[2]+n[3],s),inc(),ni[3]+1],
            [n[0]+n[2]+n[1]+n[3],heuristic(n[0]+n[2]+n[1]+n[3],s),inc(),ni[3]+1],
            [n[0]+n[1]+n[3]+n[2],heuristic(n[0]+n[1]+n[3]+n[2],s),inc(),ni[3]+1]]

def beam(begin,end,b):
    l = [[begin, heuristic(begin, end),inc(),0]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      if current[0]== end :
              dot.node(str(current[2]), str(current[0]),shape='doublecircle',fillcolor='pink',style='filled')
              print("Visited:"+str(len(visited))+" nodes \n")
              print("No visited:"+str(len(l))+" nodes \n")
              print("Nivel:"+str(current[3])+" nodes \n")
              return print("Found:"+str(i)+" nodes")
      #tmp =  sucesores(current[0],end,current)
      if current[3]< 6:
          suc =  sucesores(current[0],end,current)
          #suc.reverse()
          suc.sort(key=lambda x: int(x[1]))
          tmp = []
          for x in range(0,len(suc)):
             if x > (b-1):
                break
             tmp.append(suc[x])
          if tmp:
              for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]),label = str(x[1]))
              l.extend(tmp)
              l.sort(key=lambda x: int(x[1]))
    print("Not Found:"+str(i)+" nodes")

dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

beam("DCBA","ABCD",2)

dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited:29 nodes
#
# No visited:12 nodes
#
# Nivel:6 nodes
#
# Found:61 nodes

# %% [markdown]
# Considere el 4-puzzle horizontal, con estado inicial 1234 y estado final 4321, elabore el árbol de búsqueda de Best First con heurística
# Manhattan. ¿Cuánto es el valor de la heurística mayor calculada?

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i


def posicion(n):
  pos =[]
  for x in range(0,len(n)):
    if n[x]=="1":
      pos.append(0)
    elif n[x]=="2":
      pos.append(1)
    elif n[x]=="3":
      pos.append(2)
    elif n[x]=="4":
      pos.append(3)
  return pos

def heuristic(nodo_actual,nodo_fin):
    return  sum (abs (x - y) for (x, y) in zip(nodo_actual, nodo_fin))

def sucesores(n,s,ni):

   return [ [n[1]+n[0]+n[2]+n[3], heuristic(posicion(n[1]+n[0]+n[2]+n[3]),posicion(s)),inc(),ni[3]+1],
            [n[0]+n[2]+n[1]+n[3],heuristic(posicion(n[0]+n[2]+n[1]+n[3]),posicion(s)),inc(),ni[3]+1],
            [n[0]+n[1]+n[3]+n[2],heuristic(posicion(n[0]+n[1]+n[3]+n[2]),posicion(s)),inc(),ni[3]+1]]

def bestfirst(begin,end):
    l = [[begin, heuristic(posicion(begin),posicion(end)),inc(),0]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      if current[0]== end :
              dot.node(str(current[2]), str(current[0]),shape='doublecircle',fillcolor='pink',style='filled')
              print("Visited:"+str(len(visited))+" nodes \n")
              print("No visited:"+str(len(l))+" nodes \n")
              print("Nivel:"+str(current[3])+" nodes \n")
              return print("Found:"+str(i)+" nodes")
      tmp =  sucesores(current[0],end,current)
      #tmp.reverse()
      if tmp:
              for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]),label = str(x[1]))
              l.extend(tmp)
              l.sort(key=lambda x: int(x[1]))
    print("Not Found:"+str(i)+" nodes")

dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

bestfirst("1234","4321")

dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited:9 nodes
#
# No visited:16 nodes
#
# Nivel:6 nodes
#
# Found:25 nodes

# %% [markdown]
# Considere el 4-puzzle horizontal, con estado inicial 4213 y estado final 1234, elabore el árbol de búsqueda de Colinas con su esperanza como
# heurística (diferencia absoluta entre el estado final e inicial). ¿Cuántos niveles se generaron?

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i


def posicion(n):
  pos =[]
  for x in range(0,len(n)):
    if n[x]=="4":
      pos.append(4)
    elif n[x]=="2":
      pos.append(2)
    elif n[x]=="1":
      pos.append(1)
    elif n[x]=="3":
      pos.append(3)
  return pos

def heuristic(nodo_actual,nodo_fin):
    return  sum (abs (x - y) for (x, y) in zip(nodo_actual, nodo_fin))

def sucesores(n,s,ni):

   return [ [n[1]+n[0]+n[2]+n[3], heuristic(posicion(n[1]+n[0]+n[2]+n[3]),posicion(s)),inc(),ni[3]+1],
            [n[0]+n[2]+n[1]+n[3],heuristic(posicion(n[0]+n[2]+n[1]+n[3]),posicion(s)),inc(),ni[3]+1],
            [n[0]+n[1]+n[3]+n[2],heuristic(posicion(n[0]+n[1]+n[3]+n[2]),posicion(s)),inc(),ni[3]+1]]

def colinas(begin,end):
    b=1
    l = [[begin, heuristic(posicion(begin),posicion(end)),inc(),0]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      if current[0]== end  :
              dot.node(str(current[2]), str(current[0]),shape='doublecircle',fillcolor='pink',style='filled')
              print("Visited:"+str(len(visited))+" nodes \n")
              print("No visited:"+str(len(l))+" nodes \n")
              print("Nivel:"+str(current[3])+" nodes \n")
              return print("Found:"+str(len(visited)+len(l))+" nodes")
      #tmp =  sucesores(current[0],end,current)
      #if current[3]< 4:
      suc =  sucesores(current[0],end,current)
      #suc.reverse()
      suc.sort(key=lambda x: int(x[1]))
      tmp = []
      for x in range(0,len(suc)):
             if x > (b-1):
                break
             tmp.append(suc[x])
      if tmp:
              for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]),label = str(x[1]))
              l.extend(tmp)
              l.sort(key=lambda x: int(x[1]))
    print("Not Found:"+str(i)+" nodes")

dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

colinas("4213","1234")

dot.view()
dot.render('arbol_1234', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_1234.png')
# Out:
# Visited:5 nodes
#
# No visited:0 nodes
#
# Nivel:4 nodes
#
# Found:5 nodes

# %% [markdown]
# Considere el 4-puzzle horizontal, con estado inicial 4213 y estado final 1234, elabore el árbol de búsqueda de Beam igual a 2 con su esperanza
# como heurística (diferencia absoluta entre el estado final e inicial). ¿Cuántos niveles se generaron?

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i


def posicion(n):
  pos =[]
  for x in range(0,len(n)):
    if n[x]=="4":
      pos.append(4)
    elif n[x]=="2":
      pos.append(2)
    elif n[x]=="1":
      pos.append(1)
    elif n[x]=="3":
      pos.append(3)
  return pos

def heuristic(nodo_actual,nodo_fin):
    return  sum (abs (x - y) for (x, y) in zip(nodo_actual, nodo_fin))

def sucesores(n,s,ni):

   return [ [n[1]+n[0]+n[2]+n[3], heuristic(posicion(n[1]+n[0]+n[2]+n[3]),posicion(s)),inc(),ni[3]+1],
            [n[0]+n[2]+n[1]+n[3],heuristic(posicion(n[0]+n[2]+n[1]+n[3]),posicion(s)),inc(),ni[3]+1],
            [n[0]+n[1]+n[3]+n[2],heuristic(posicion(n[0]+n[1]+n[3]+n[2]),posicion(s)),inc(),ni[3]+1]]

def beam(begin,end,b):
    l = [[begin, heuristic(posicion(begin),posicion(end)),inc(),0]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      if current[0]== end :
              dot.node(str(current[2]), str(current[0]),shape='doublecircle',fillcolor='pink',style='filled')
              print("Visited:"+str(len(visited))+" nodes \n")
              print("No visited:"+str(len(l))+" nodes \n")
              print("Nivel:"+str(current[3])+" nodes \n")
              return print("Found:"+str(len(visited)+len(l))+" nodes")
      #tmp =  sucesores(current[0],end,current)
      suc =  sucesores(current[0],end,current)
      suc.sort(key=lambda x: int(x[1]))
      tmp = []
      for x in range(0,len(suc)):
             if x > (b-1):
                break
             tmp.append(suc[x])
      if tmp:
              for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]),label = str(x[1]))
              l.extend(tmp)
              l.sort(key=lambda x: int(x[1]))
    print("Not Found:"+str(i)+" nodes")

dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

beam("4213","1234",2)

dot.view()
dot.render('arbol_1234', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_1234.png')
# Out:
# Visited:5 nodes
#
# No visited:4 nodes
#
# Nivel:4 nodes
#
# Found:9 nodes

# %% [markdown]
# Considerar un arreglo con los siguientes numeros [2,3,1,4] el problema es ordenar [1,2,3,4] Mostrar un arbol de busqueda utilizando A* ***con heuristica fuera de lugar***

# %%
# posiciones
# 2431 4213 4321
# 1023 0132 0213

from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i

def heuristic(nodo_actual,nodo_fin):
    return [x != y for (x, y) in zip(nodo_actual, nodo_fin)].count(True)

def sucesores(n,s,ni):

   return [[[n[1],n[0],n[2],n[3]],heuristic([n[1],n[0],n[2],n[3]],s)+ni[3]+1,inc(),ni[3]+1],
            [[n[0],n[2],n[1],n[3]],heuristic([n[0],n[2],n[1],n[3]],s)+ni[3]+1,inc(),ni[3]+1],
            [[n[0],n[1],n[3],n[2]],heuristic([n[0],n[1],n[3],n[2]],s)+ni[3]+1,inc(),ni[3]+1]]

def A_START(begin,end):
    l = [[begin, heuristic(begin, end),inc(),0]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      #visited.extend([current[0]])
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      if current[0]== end :
              dot.node(str(current[2]), str(current[0]),shape='doublebox',fillcolor='pink',style='filled')
              print("Visited:"+str(len(visited))+" nodes \n")
              print("No visited:"+str(len(l))+" nodes \n")
              print("Nivel:"+str(current[3])+" nodes \n")
              return print("Found:"+str(i)+" nodes")
      tmp =  sucesores(current[0],end,current)
      if tmp:
              for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]),label = str(x[1]))
              l.extend(tmp)
              l.sort(key=lambda x: int(x[1]))
    print("Not Found:"+str(i)+" nodes")

dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='box',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')


A_START([2,3,1,4],[1,2,3,4])

dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# ...
# Visited:4 nodes
#
# No visited:6 nodes
#
# Nivel:2 nodes
#
# Found:10 nodes
