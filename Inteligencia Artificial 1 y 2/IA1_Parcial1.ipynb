# %% [markdown]
# Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo caballo en la posición c3. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por anchura, sin generar nodos repetidos considerando todo el árbol, tomando en cuenta un orden alfanumérico descendente para los sucesores. ¿Cuántos niveles tiene el árbol? (-1 si se encicla)

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i


def succesor(n):
    if n[0]==   'C3': return [['A2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['C1',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B3',n[1]+1,inc()],['A2',n[1]+1,inc()]]
    elif n[0]== 'B3': return [['A1',n[1]+1,inc()],['C1',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A3',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['C2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'C2': return [['A1',n[1]+1,inc()],['A3',n[1]+1,inc()]]






def breadthlimitedDesc(begin,end):
    l = [[begin,0,inc()]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]))
      if current[0]== end:
          dot.node(str(current[2]), str(current[0]),shape='doublecircle')
          print("Visited:"+str(len(visited))+" nodes \n")
          print("No visited:"+str(len(l))+" nodes \n")
          print("Nivel:"+str(current[1])+" nodes \n")

          return print("Found:"+str(i)+" nodes")

      tmp =  succesor(current)
      tmp.reverse()
      if tmp:
              for x in tmp:
                  dot.node(str(x[2]), str(x[0]))
                  dot.edge(str(current[2]), str(x[2]))
              l.extend(tmp)
    print("Not Found:"+str(i)+" nodes")
'''

def succesor(n):
    if n[0]==   'C3': return [['A2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['C1',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B3',n[1]+1,inc()],['A2',n[1]+1,inc()]]
    elif n[0]== 'B3': return [['A1',n[1]+1,inc()],['C1',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A3',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['C2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'C2': return [['A1',n[1]+1,inc()],['A3',n[1]+1,inc()]]

def breadthlimitedASC(begin,end):
    l = [[begin,0,inc(),0]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      if current[0]== end:
          dot.node(str(current[2]), str(current[0]),fillcolor='pink',style='filled',shape='doublecircle')
          print("Visited:"+str(len(visited))+" nodes \n")
          print("No visited:"+str(len(l))+" nodes \n")
          return print("Found:"+str(i)+" nodes")
      tmp =  succesor(current)
      if tmp:
              for x in tmp:
                  dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                  dot.edge(str(current[2]), str(x[2]))
              l.extend(tmp)
    print("Not Found:"+str(i)+" nodes")
'''



dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

breadthlimitedDesc('C3', 'A1')
#breadthlimitedASC('C2', 'A1')




dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited:23 nodes
#
# No visited:22 nodes
#
# Nivel:4 nodes
#
# Found:45 nodes

# %% [markdown]
# Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo torre en la posición c2. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por profundidad, sin generar nodos repetidos en todo el árbol, tomando en cuenta un orden alfanumérico descendente para los sucesores. ¿Cuántos nodos fueron visitados?

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i

'''
# Numero de grados el numero de hijos en el arbol
# se enclico esa mierda cagadales
'''


'''


def succesor(n):
    if n[0]==   'A1': return [['B2',n[1]+1,inc()],['B1',n[1]+1,inc()],['A2',n[1]+1,inc()]]

    elif n[0]== 'B1': return [['C2',n[1]+1,inc()],['C1',n[1]+1,inc()],['B2',n[1]+1,inc()],['A2',n[1]+1,inc()],['A1',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['C2',n[1]+1,inc()],['B2',n[1]+1,inc()],['B1',n[1]+1,inc()]]

    elif n[0]== 'A2': return [['B3',n[1]+1,inc()],['B2',n[1]+1,inc()],['B1',n[1]+1,inc()],['A3',n[1]+1,inc()],['A1',n[1]+1,inc()]]

    elif n[0]== 'B2': return [
                              ['C3',n[1]+1,inc()],['C2',n[1]+1,inc()],['C1',n[1]+1,inc()],
                              ['B3',n[1]+1,inc()],['B1',n[1]+1,inc()],
                              ['A3',n[1]+1,inc()], ['A2',n[1]+1,inc()],['A1',n[1]+1,inc()]
     ]


    elif n[0]== 'C2': return [['C3',n[1]+1,inc()],['C1',n[1]+1,inc()],['B3',n[1]+1,inc()],['B1',n[1]+1,inc()],['B2',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['B3',n[1]+1,inc()],['B2',n[1]+1,inc()],['A2',n[1]+1,inc()]]
    elif n[0]== 'B3': return [['C3',n[1]+1,inc()],['C2',n[1]+1,inc()],['B2',n[1]+1,inc()],['A3',n[1]+1,inc()],['A2',n[1]+1,inc()]]
    elif n[0]== 'C3': return [['C2',n[1]+1,inc()],['B3',n[1]+1,inc()],['B2',n[1]+1,inc()]]
    else : return None


'''
def succesor(n):
    if n[0]==   'C2': return [['B2',n[1]+1,inc()],['C1',n[1]+1,inc()]]
    elif n[0]== 'B2': return [['A2',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['A1',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B1',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A1',n[1]+1,inc()]]






def profundidad (begin, end):
    l = [[begin,0,inc()]]
    visited = []
    while l:
        current = l.pop(0)
        visited.append(current)
        dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
        if current[0]== end:
            dot.node(str(current[2]), str(current[0]),fillcolor='pink',style='filled',shape='doublecircle')
            print("Visited: "+str(len(visited))+" nodes")
            print("No visited: "+str(len(l))+" nodes")
            return print("Found:"+str(i)+" nodes")
        tmp =  succesor(current)
        tmp.reverse() # esta es para la forma descente si los descomentas
        if tmp:
                for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]))
                tmp.extend(l)
                l = tmp

    print("Not Found:"+str(i)+" nodes")




dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

#profundidad('C2', 'A1')
profundidad('C2', 'A1')



dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited: 4 nodes
# No visited: 1 nodes
# Found:5 nodes

# %% [markdown]
# Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo caballo en la posición c3. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por anchura, utilizando la estrategia de buscar solución en los sucesores para ahorrar un nivel (los sucesores evaluados se consideran nodos del árbol pero sin visitar), tomando en cuenta un orden alfanumérico ascendente para los sucesores. ¿Cuántos nodos fueron visitados?

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i


def succesor(n):
    if n[0]==   'C3': return [['A2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['C1',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B3',n[1]+1,inc()],['A2',n[1]+1,inc()]]
    elif n[0]== 'B3': return [['A1',n[1]+1,inc()],['C1',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A3',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['C2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'C2': return [['A1',n[1]+1,inc()],['A3',n[1]+1,inc()]]






def breadthlimitedDesc(begin,end):
    l = [[begin,0,inc()]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      dot.node(str(current[2]), str(current[0]))
      if current[0]== end:
          dot.node(str(current[2]), str(current[0]),fillcolor='pink',style='filled',shape='doublecircle')
          #dot.node(str(current[2]), str(current[0]),shape='doublecircle')
          print("Visited:"+str(len(visited))+" nodes \n")
          print("No visited:"+str(len(l))+" nodes \n")
          print("Nivel:"+str(current[1])+" nodes \n")

          return print("Found:"+str(i)+" nodes")

      tmp =  succesor(current)
      #tmp.reverse()
      if tmp:
              for x in tmp:
                  dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                  dot.edge(str(current[2]), str(x[2]))
              l.extend(tmp)
    print("Not Found:"+str(i)+" nodes")
'''

def succesor(n):
    if n[0]==   'C3': return [['A2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['C1',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B3',n[1]+1,inc()],['A2',n[1]+1,inc()]]
    elif n[0]== 'B3': return [['A1',n[1]+1,inc()],['C1',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A3',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['C2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'C2': return [['A1',n[1]+1,inc()],['A3',n[1]+1,inc()]]

def breadthlimitedASC(begin,end):
    l = [[begin,0,inc(),0]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      if current[0]== end:
          dot.node(str(current[2]), str(current[0]),fillcolor='pink',style='filled',shape='doublecircle')
          print("Visited:"+str(len(visited))+" nodes \n")
          print("No visited:"+str(len(l))+" nodes \n")
          return print("Found:"+str(i)+" nodes")
      tmp =  succesor(current)
      if tmp:
              for x in tmp:
                  dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                  dot.edge(str(current[2]), str(x[2]))
              l.extend(tmp)
    print("Not Found:"+str(i)+" nodes")
'''



dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

breadthlimitedDesc('C3', 'A1')
#breadthlimitedASC('C2', 'A1')




dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited:16 nodes
#
# No visited:15 nodes
#
# Nivel:4 nodes
#
# Found:31 nodes

# %% [markdown]
# Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo caballo en la posición c3. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por profundidad, sin generar nodos repetidos en un mismo camino, tomando en cuenta un orden alfanumérico ascendente para los sucesores. Independientemente del camino seleccionado, ¿cuántas soluciones tiene el árbol?

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i





def succesor(n):
    if n[0]==   'C3': return [['A2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A3',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['C2',n[1]+1,inc()]]
    elif n[0]== 'C2': return [['A1',n[1]+1,inc()]]






def profundidad (begin, end):
    l = [[begin,0,inc()]]
    visited = []
    while l:
        current = l.pop(0)
        visited.append(current)
        dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
        if current[0]== end:
            dot.node(str(current[2]), str(current[0]),fillcolor='pink',style='filled',shape='doublecircle')
            print("Visited: "+str(len(visited))+" nodes")
            print("No visited: "+str(len(l))+" nodes")
            return print("Found:"+str(i)+" nodes")
        tmp =  succesor(current)
        #tmp.reverse() # esta es para la forma descente si los descomentas
        if tmp:
                for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]))
                tmp.extend(l)
                l = tmp

    print("Not Found:"+str(i)+" nodes")




dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

#profundidad('C2', 'A1')
profundidad('C3', 'A1')



dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited: 6 nodes
# No visited: 0 nodes
# Found:6 nodes

# %% [markdown]
# Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo torre en la posición c2. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por anchura, tomando en cuenta un orden alfanumérico ascendente para los sucesores. **¿Cuál es el grado del árbol generado? RESPUESTA ES 2 El maximo cantidad de hijos que tiene el nodo.**
# **¿Cuántos nodos no fueron visitados?**
#
# **¿Cuántos nodos tiene el árbol generado?**
#  **¿cuántas soluciones tiene el árbol?**

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i




def succesor(n):
    if n[0]==   'C2': return [['B2',n[1]+1,inc()],['C1',n[1]+1,inc()]]
    elif n[0]== 'B2': return [['A2',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['A1',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B1',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A1',n[1]+1,inc()]]






def breadthlimitedASC(begin,end):
    l = [[begin,0,inc()]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      dot.node(str(current[2]), str(current[0]))
      if current[0]== end:
          dot.node(str(current[2]), str(current[0]),fillcolor='pink',style='filled',shape='doublecircle')
          #dot.node(str(current[2]), str(current[0]),shape='doublecircle')
          print("Visited:"+str(len(visited))+" nodes \n")
          print("No visited:"+str(len(l))+" nodes \n")
          print("Nivel:"+str(current[1])+" nodes \n")

          return print("Found:"+str(i)+" nodes")

      tmp =  succesor(current)
      #tmp.reverse() #Descendente si se descomenta
      if tmp:
              for x in tmp:
                  dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                  dot.edge(str(current[2]), str(x[2]))
              l.extend(tmp)
    print("Not Found:"+str(i)+" nodes")




dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

breadthlimitedASC('C2', 'A1')



dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited:6 nodes
#
# No visited:1 nodes
#
# Nivel:3 nodes
#
# Found:7 nodes

# %% [markdown]
# Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo caballo en la posición c3. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un **árbol de búsqueda por profundidad**, sin generar nodos repetidos en un mismo camino, tomando en cuenta un orden alfanumérico ascendente para los sucesores. ¿Cuántos movimientos tiene que hacer el caballo para llegar a la solución? (-1 si se encicla)

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i




def succesor(n):
    if n[0]==   'C2': return [['B2',n[1]+1,inc()],['C1',n[1]+1,inc()]]
    elif n[0]== 'B2': return [['A2',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['A1',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B1',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A1',n[1]+1,inc()]]





def profundidad (begin, end):
    l = [[begin,0,inc()]]
    visited = []
    while l:
        current = l.pop(0)
        visited.append(current)
        dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
        if current[0]== end:
            dot.node(str(current[2]), str(current[0]),fillcolor='pink',style='filled',shape='doublecircle')
            print("Visited: "+str(len(visited))+" nodes")
            print("No visited: "+str(len(l))+" nodes")
            return print("Found:"+str(i)+" nodes")
        tmp =  succesor(current)
        #tmp.reverse() # esta es para la forma descente si los descomentas
        if tmp:
                for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]))
                tmp.extend(l)
                l = tmp

    print("Not Found:"+str(i)+" nodes")




dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

profundidad('C2', 'A1')




dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited: 4 nodes
# No visited: 1 nodes
# Found:5 nodes

# %% [markdown]
# Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo caballo en la posición c3. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por profundidad, sin generar nodos repetidos en un mismo camino, tomando en cuenta un orden alfanumérico ascendente para los sucesores. ¿Cuántos nodos fueron visitados?

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i







def succesor(n):
    if n[0]==   'C3': return [['A2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A3',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['C2',n[1]+1,inc()]]
    elif n[0]== 'C2': return [['A1',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['C1',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B3',n[1]+1,inc()]]
    elif n[0]== 'B3': return [['A1',n[1]+1,inc()]]


def profundidad (begin, end):
    l = [[begin,0,inc()]]
    visited = []
    while l:
        current = l.pop(0)
        visited.append(current)
        dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
        if current[0]== end:
            dot.node(str(current[2]), str(current[0]),fillcolor='pink',style='filled',shape='doublecircle')
            print("Visited: "+str(len(visited))+" nodes")
            print("No visited: "+str(len(l))+" nodes")
            return print("Found:"+str(i)+" nodes")
        tmp =  succesor(current)
        #tmp.reverse() # esta es para la forma descente si los descomentas
        if tmp:
                for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]))
                tmp.extend(l)
                l = tmp

    print("Not Found:"+str(i)+" nodes")




dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

profundidad('C3', 'A1')




dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited: 5 nodes
# No visited: 1 nodes
# Found:6 nodes

# %% [markdown]
# Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo caballo en la posición c3. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por anchura, utilizando la estrategia de buscar solución en los sucesores para ahorrar un nivel (los sucesores evaluados se consideran nodos del árbol pero sin visitar), tomando en cuenta un orden alfanumérico ascendente para los sucesores. ¿Cuántos nodos no fueron visitados?

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i





'''
def succesor(n):
    if n[0]==   'C3': return [['A2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['C1',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A3',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['C2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'C2': return [['A1',n[1]+1,inc()],['A3',n[1]+1,inc()]]
'''


def succesor(n):
    if n[0]==   'C3': return [['A2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A3',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['C2',n[1]+1,inc()]]
    elif n[0]== 'C2': return [['A1',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['C1',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B3',n[1]+1,inc()]]
    elif n[0]== 'B3': return [['A1',n[1]+1,inc()]]


def breadthlimitedASC(begin,end):
    l = [[begin,0,inc()]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      dot.node(str(current[2]), str(current[0]))
      if current[0]== end:
          dot.node(str(current[2]), str(current[0]),fillcolor='pink',style='filled',shape='doublecircle')
          #dot.node(str(current[2]), str(current[0]),shape='doublecircle')
          print("Visited:"+str(len(visited))+" nodes \n")
          print("No visited:"+str(len(l))+" nodes \n")
          print("Nivel:"+str(current[1])+" nodes \n")

          return print("Found:"+str(i)+" nodes")

      tmp =  succesor(current)
      tmp.reverse() #Descendente si se descomenta
      if tmp:
              for x in tmp:
                  dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                  dot.edge(str(current[2]), str(x[2]))
              l.extend(tmp)
    print("Not Found:"+str(i)+" nodes")




dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

breadthlimitedASC('C3', 'A1')



dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited:8 nodes
#
# No visited:1 nodes
#
# Nivel:4 nodes
#
# Found:9 nodes
