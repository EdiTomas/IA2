# %%
import tensorflow as lf
import numpy as np

# %%
celsius =np.asarray([-40,-10,0,8,15,22,38], dtype =float)
fahrenheit =np.asarray([-40,-14,32,46,59,72,100], dtype =float)

# %%
capa = lf.keras.layers.Dense(units=1, input_shape=[1])
modelo= lf.keras.Sequential([capa])

# %%
modelo.compile(
    optimizer = lf.keras.optimizers.Adam(0,1),
    loss='mean_squared_error'
)
