# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i

'''
# Numero de grados el numero de hijos en el arbol
'''
def succesor(n):
    if n[0]==   'A1': return [['A2',n[1]+1,inc()],['B1',n[1]+1,inc()],['B2',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A1',n[1]+1,inc()],['A2',n[1]+1,inc()],['B2',n[1]+1,inc()],['C1',n[1]+1,inc()],['C2',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B1',n[1]+1,inc()],['B2',n[1]+1,inc()],['C2',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['A1',n[1]+1,inc()],['A3',n[1]+1,inc()],['B1',n[1]+1,inc()],['B2',n[1]+1,inc()],['B3',n[1]+1,inc()]]
    elif n[0]== 'B2': return [['A1',n[1]+1,inc()],['A2',n[1]+1,inc()],['A3',n[1]+1,inc()],['B1',n[1]+1,inc()],['B3',n[1]+1,inc()],
     ['C1',n[1]+1,inc()],['C2',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'C2': return [['B1',n[1]+1,inc()],['B2',n[1]+1,inc()],['B3',n[1]+1,inc()],['C1',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['A2',n[1]+1,inc()],['B2',n[1]+1,inc()],['B3',n[1]+1,inc()]]
    elif n[0]== 'B3': return [['A2',n[1]+1,inc()],['A3',n[1]+1,inc()],['B2',n[1]+1,inc()],['C2',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'C3': return [['B2',n[1]+1,inc()],['B3',n[1]+1,inc()],['C2',n[1]+1,inc()]]

    else : return None

'''
def profundidad (begin, end):
    l = [[begin,0,inc()]]
    visited = []
    while l:
        current = l.pop(0)
        visited.append(current)
        dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
        if current[0]== end:
            dot.node(str(current[2]), str(current[0]),fillcolor='pink',style='filled',shape='doublecircle')
            print("Visited: "+str(len(visited))+" nodes")
            print("No visited: "+str(len(l))+" nodes")
            return print("Found:"+str(i)+" nodes")
        tmp =  succesor(current)
        #tmp.reverse()
        if tmp:
                for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]))
                tmp.extend(l)
                l = tmp

    print("Not Found:"+str(i)+" nodes")

'''

def breadthlimitedASC(begin,end):
    l = [[begin,0,inc(),0]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]))
      if current[0]== end:
          dot.node(str(current[2]), str(current[0]),shape='doublecircle')
          print("Visited:"+str(len(visited))+" nodes \n")
          print("No visited:"+str(len(l))+" nodes \n")
          return print("Found:"+str(i)+" nodes")
      tmp =  succesor(current)
      if tmp:
              for x in tmp:
                  dot.node(str(x[2]), str(x[0]))
                  dot.edge(str(current[2]), str(x[2]))
              l.extend(tmp)
    print("Not Found:"+str(i)+" nodes")




dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

#breadthlimitedASC('C3', 'A1')
breadthlimitedASC('C2', 'A1')




dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited:7 nodes
#
# No visited:23 nodes
#
# Found:30 nodes

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i

'''
# Numero de grados el numero de hijos en el arbol
# se enclico esa mierda cagadales
'''
def succesor(n):
    if n[0]==   'A1': return [['A2',n[1]+1,inc()],['B1',n[1]+1,inc()],['B2',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A1',n[1]+1,inc()],['A2',n[1]+1,inc()],['B2',n[1]+1,inc()],['C1',n[1]+1,inc()],['C2',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B1',n[1]+1,inc()],['B2',n[1]+1,inc()],['C2',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['A1',n[1]+1,inc()],['A3',n[1]+1,inc()],['B1',n[1]+1,inc()],['B2',n[1]+1,inc()],['B3',n[1]+1,inc()]]
    elif n[0]== 'B2': return [['A1',n[1]+1,inc()],['A2',n[1]+1,inc()],['A3',n[1]+1,inc()],['B1',n[1]+1,inc()],['B3',n[1]+1,inc()],
     ['C1',n[1]+1,inc()],['C2',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'C2': return [['B1',n[1]+1,inc()],['B2',n[1]+1,inc()],['B3',n[1]+1,inc()],['C1',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['A2',n[1]+1,inc()],['B2',n[1]+1,inc()],['B3',n[1]+1,inc()]]
    elif n[0]== 'B3': return [['A2',n[1]+1,inc()],['A3',n[1]+1,inc()],['B2',n[1]+1,inc()],['C2',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'C3': return [['B2',n[1]+1,inc()],['B3',n[1]+1,inc()],['C2',n[1]+1,inc()]]

    else : return None


def profundidad (begin, end):
    l = [[begin,0,inc()]]
    visited = []
    while l:
        current = l.pop(0)
        visited.append(current)
        dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
        if current[0]== end:
            dot.node(str(current[2]), str(current[0]),fillcolor='pink',style='filled',shape='doublecircle')
            print("Visited: "+str(len(visited))+" nodes")
            print("No visited: "+str(len(l))+" nodes")
            return print("Found:"+str(i)+" nodes")
        tmp =  succesor(current)
        tmp.reverse() # esta es para la forma descente si los descomentas
        if tmp:
                for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]))
                tmp.extend(l)
                l = tmp

    print("Not Found:"+str(i)+" nodes")




dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

profundidad('C3', 'A1')




dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-edabce12c564> in <cell line: 57>()
#      55 dot.edge_attr.update(color='blue4')
#      56
# ---> 57 profundidad('C3', 'A1')
#      58
#      59
#
# <ipython-input-4-edabce12c564> in profundidad(begin, end)
#      27     l = [[begin,0,inc()]]
#      28     visited = []
# ---> 29     while l:
#      30         current = l.pop(0)
#      31         visited.append(current)
#
# KeyboardInterrupt:

# %% [markdown]
# Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo caballo en la posición c3. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por anchura, utilizando la estrategia de buscar solución en los sucesores para ahorrar un nivel (los sucesores evaluados se consideran nodos del árbol pero sin visitar), tomando en cuenta un orden alfanumérico ascendente para los sucesores. ¿Cuántos nodos no fueron visitados?

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i



def succesor(n):
    if n[0]==   'C3': return [['A2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['C1',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B3',n[1]+1,inc()],['A2',n[1]+1,inc()]]
    elif n[0]== 'B3': return [['A1',n[1]+1,inc()],['C1',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A3',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['C2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'C2': return [['A1',n[1]+1,inc()],['A3',n[1]+1,inc()]]

    else : return None




def breadthlimitedASC(begin,end):
    l = [[begin,0,inc(),0]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      if current[0]== end:
          dot.node(str(current[2]), str(current[0]),fillcolor='pink',style='filled',shape='doublecircle')
          print("Visited:"+str(len(visited))+" nodes \n")
          print("No visited:"+str(len(l))+" nodes \n")
          return print("Found:"+str(i)+" nodes")
      tmp =  succesor(current)
      if tmp:
              for x in tmp:
                  dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                  dot.edge(str(current[2]), str(x[2]))
              l.extend(tmp)
    print("Not Found:"+str(i)+" nodes")




dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

breadthlimitedASC('C3', 'A1')
#breadthlimitedASC('C2', 'A1')




dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited:16 nodes
#
# No visited:15 nodes
#
# Found:31 nodes

# %% [markdown]
# **Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo caballo en la posición c3. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por profundidad, sin generar nodos repetidos en un mismo camino, tomando en cuenta un orden alfanumérico ascendente para los sucesores. ¿Cuántos nodos tiene el árbol?**

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i

'''
# Numero de grados el numero de hijos en el arbol
# se enclico esa mierda cagadales
'''
def succesor(n):
    if n[0]==   'A1': return [['A2',n[1]+1,inc()],['B1',n[1]+1,inc()],['B2',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A1',n[1]+1,inc()],['A2',n[1]+1,inc()],['B2',n[1]+1,inc()],['C1',n[1]+1,inc()],['C2',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B1',n[1]+1,inc()],['B2',n[1]+1,inc()],['C2',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['A1',n[1]+1,inc()],['A3',n[1]+1,inc()],['B1',n[1]+1,inc()],['B2',n[1]+1,inc()],['B3',n[1]+1,inc()]]
    elif n[0]== 'B2': return [['A1',n[1]+1,inc()],['A2',n[1]+1,inc()],['A3',n[1]+1,inc()],['B1',n[1]+1,inc()],['B3',n[1]+1,inc()],
     ['C1',n[1]+1,inc()],['C2',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'C2': return [['B1',n[1]+1,inc()],['B2',n[1]+1,inc()],['B3',n[1]+1,inc()],['C1',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['A2',n[1]+1,inc()],['B2',n[1]+1,inc()],['B3',n[1]+1,inc()]]
    elif n[0]== 'B3': return [['A2',n[1]+1,inc()],['A3',n[1]+1,inc()],['B2',n[1]+1,inc()],['C2',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'C3': return [['B2',n[1]+1,inc()],['B3',n[1]+1,inc()],['C2',n[1]+1,inc()]]

    else : return None


def profundidad (begin, end):
    l = [[begin,0,inc()]]
    visited = []
    while l:
        current = l.pop(0)
        visited.append(current)
        dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
        if current[0]== end:
            dot.node(str(current[2]), str(current[0]),fillcolor='pink',style='filled',shape='doublecircle')
            print("Visited: "+str(len(visited))+" nodes")
            print("No visited: "+str(len(l))+" nodes")
            return print("Found:"+str(i)+" nodes")
        tmp =  succesor(current)
        #tmp.reverse() # esta es para la forma descente si los descomentas
        if tmp:
                for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]))
                tmp.extend(l)
                l = tmp

    print("Not Found:"+str(i)+" nodes")




dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

profundidad('C3', 'A1')




dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited: 3 nodes
# No visited: 9 nodes
# Found:12 nodes

# %% [markdown]
# **Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo caballo en la posición c3. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por anchura, sin generar nodos repetidos en un mismo camino, tomando en cuenta un orden alfanumérico ascendente para los sucesores. ¿En qué nivel se encontró solución? (-1 si no se encontró)** Se encontro en nivel 2

# %% [markdown]
# **Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo caballo en la posición c3. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por anchura, utilizando la estrategia de buscar solución en los sucesores para ahorrar un nivel (los sucesores evaluados se consideran nodos del árbol pero sin visitar), tomando en cuenta un orden alfanumérico ascendente para los sucesores. ¿Cuál es el grado del árbol generado?**  Respuesta es 18

# %% [markdown]
# **Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo torre en la posición c2. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por profundidad, sin generar nodos repetidos en todo el árbol, tomando en cuenta un orden alfanumérico descendente para los sucesores. ¿Cuántos nodos fueron visitados?**

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i

'''
# Numero de grados el numero de hijos en el arbol
# se enclico esa mierda cagadales
'''


'''
def succesor(n):
    if n[0]==   'A1': return [['A2',n[1]+1,inc()],['B1',n[1]+1,inc()],['B2',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A1',n[1]+1,inc()],['A2',n[1]+1,inc()],['B2',n[1]+1,inc()],['C1',n[1]+1,inc()],['C2',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B1',n[1]+1,inc()],['B2',n[1]+1,inc()],['C2',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['A1',n[1]+1,inc()],['A3',n[1]+1,inc()],['B1',n[1]+1,inc()],['B2',n[1]+1,inc()],['B3',n[1]+1,inc()]]
    elif n[0]== 'B2': return [['A1',n[1]+1,inc()],['A2',n[1]+1,inc()],['A3',n[1]+1,inc()],['B1',n[1]+1,inc()],['B3',n[1]+1,inc()],
     ['C1',n[1]+1,inc()],['C2',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'C2': return [['B1',n[1]+1,inc()],['B2',n[1]+1,inc()],['B3',n[1]+1,inc()],['C1',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['A2',n[1]+1,inc()],['B2',n[1]+1,inc()],['B3',n[1]+1,inc()]]
    elif n[0]== 'B3': return [['A2',n[1]+1,inc()],['A3',n[1]+1,inc()],['B2',n[1]+1,inc()],['C2',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'C3': return [['B2',n[1]+1,inc()],['B3',n[1]+1,inc()],['C2',n[1]+1,inc()]]
    else : return None
'''


def succesor(n):
    if n[0]==   'A1': return [['B2',n[1]+1,inc()],['B1',n[1]+1,inc()],['A2',n[1]+1,inc()]]

    elif n[0]== 'B1': return [['C2',n[1]+1,inc()],['C1',n[1]+1,inc()],['B2',n[1]+1,inc()],['A2',n[1]+1,inc()],['A1',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['C2',n[1]+1,inc()],['B2',n[1]+1,inc()],['B1',n[1]+1,inc()]]

    elif n[0]== 'A2': return [['B3',n[1]+1,inc()],['B2',n[1]+1,inc()],['B1',n[1]+1,inc()],['A3',n[1]+1,inc()],['A1',n[1]+1,inc()]]

    elif n[0]== 'B2': return [
                              ['C3',n[1]+1,inc()],['C2',n[1]+1,inc()],['C1',n[1]+1,inc()],
                              ['B3',n[1]+1,inc()],['B1',n[1]+1,inc()],
                              ['A3',n[1]+1,inc()], ['A2',n[1]+1,inc()],['A1',n[1]+1,inc()]
     ]


    elif n[0]== 'C2': return [['C3',n[1]+1,inc()],['C1',n[1]+1,inc()],['B3',n[1]+1,inc()],['B1',n[1]+1,inc()],['B2',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['B3',n[1]+1,inc()],['B2',n[1]+1,inc()],['A2',n[1]+1,inc()]]
    elif n[0]== 'B3': return [['C3',n[1]+1,inc()],['C2',n[1]+1,inc()],['B2',n[1]+1,inc()],['A3',n[1]+1,inc()],['A2',n[1]+1,inc()]]
    elif n[0]== 'C3': return [['C2',n[1]+1,inc()],['B3',n[1]+1,inc()],['B2',n[1]+1,inc()]]
    else : return None




def profundidad (begin, end):
    l = [[begin,0,inc()]]
    visited = []
    while l:
        current = l.pop(0)
        visited.append(current)
        dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
        if current[0]== end:
            dot.node(str(current[2]), str(current[0]),fillcolor='pink',style='filled',shape='doublecircle')
            print("Visited: "+str(len(visited))+" nodes")
            print("No visited: "+str(len(l))+" nodes")
            return print("Found:"+str(i)+" nodes")
        tmp =  succesor(current)
        tmp.reverse() # esta es para la forma descente si los descomentas
        if tmp:
                for x in tmp:
                    dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                    dot.edge(str(current[2]), str(x[2]))
                tmp.extend(l)
                l = tmp

    print("Not Found:"+str(i)+" nodes")




dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

#profundidad('C2', 'A1')
profundidad('C3', 'A1')



dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited: 3 nodes
# No visited: 9 nodes
# Found:12 nodes

# %% [markdown]
# **Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo caballo en la posición c3. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por anchura, utilizando la estrategia de buscar solución en los sucesores para ahorrar un nivel (los sucesores evaluados se consideran nodos del árbol pero sin visitar), tomando en cuenta un orden alfanumérico ascendente para los sucesores. ¿Cuántos niveles fueron generados? (-1 si se encicla)** Nivel 2

# %% [markdown]
# **Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo torre en la posición c2. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por profundidad, sin generar nodos repetidos en todo el árbol, tomando en cuenta un orden alfanumérico descendente para los sucesores. ¿Cuál es el grado del árbol generado?** R 8

# %% [markdown]
# **Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo caballo en la posición c3. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por profundidad, sin generar nodos repetidos en un mismo camino, tomando en cuenta un orden alfanumérico ascendente para los sucesores. Independientemente del camino seleccionado, ¿cuántas soluciones tiene el árbol?** Creo que es 1

# %% [markdown]
# **Considere un tablero 3x3 utilizando la nomenclatura de ajedrez y con una única pieza tipo caballo en la posición c3. El objetivo es que esta pieza, mediante sus reglas de movimientos, llegue a la posición a1 mediante n pasos. Elabore un árbol de búsqueda por anchura, sin generar nodos repetidos en un mismo camino, tomando en cuenta un orden alfanumérico ascendente para los sucesores. ¿Cuántos movimientos del caballo fueron necesarios para llegar a la solución? (-1 si se encicla)**

# %%
from graphviz import Graph
i=0
def inc():
    global i
    i+=1
    return i




'''
# Numero de grados el numero de hijos en el arbol

def succesor(n):
    if n[0]==   'A1': return [['A2',n[1]+1,inc()],['B1',n[1]+1,inc()],['B2',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A1',n[1]+1,inc()],['A2',n[1]+1,inc()],['B2',n[1]+1,inc()],['C1',n[1]+1,inc()],['C2',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B1',n[1]+1,inc()],['B2',n[1]+1,inc()],['C2',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['A1',n[1]+1,inc()],['A3',n[1]+1,inc()],['B1',n[1]+1,inc()],['B2',n[1]+1,inc()],['B3',n[1]+1,inc()]]
    elif n[0]== 'B2': return [['A1',n[1]+1,inc()],['A2',n[1]+1,inc()],['A3',n[1]+1,inc()],['B1',n[1]+1,inc()],['B3',n[1]+1,inc()],
     ['C1',n[1]+1,inc()],['C2',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'C2': return [['B1',n[1]+1,inc()],['B2',n[1]+1,inc()],['B3',n[1]+1,inc()],['C1',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['A2',n[1]+1,inc()],['B2',n[1]+1,inc()],['B3',n[1]+1,inc()]]
    elif n[0]== 'B3': return [['A2',n[1]+1,inc()],['A3',n[1]+1,inc()],['B2',n[1]+1,inc()],['C2',n[1]+1,inc()],['C3',n[1]+1,inc()]]
    elif n[0]== 'C3': return [['B2',n[1]+1,inc()],['B3',n[1]+1,inc()],['C2',n[1]+1,inc()]]

    else : return None

'''

# a3 b3 c3
# a2 b2 c2
# a1 b1 c1

# Movimientos
# c3->a2
# c3->b1

# a2->c1
# c1->b3
# b3->a1

# bl->a3
# a3->c2
# c2->a1


def succesor(n):
    if n[0]==   'C3': return [['A2',n[1]+1,inc()],['B1',n[1]+1,inc()]]
    elif n[0]== 'A2': return [['C1',n[1]+1,inc()]]
    elif n[0]== 'C1': return [['B3',n[1]+1,inc()]]
    elif n[0]== 'B3': return [['A1',n[1]+1,inc()]]
    elif n[0]== 'B1': return [['A3',n[1]+1,inc()]]
    elif n[0]== 'A3': return [['C2',n[1]+1,inc()]]
    elif n[0]== 'C2': return [['A1',n[1]+1,inc()]]

    else : return None



def breadthlimitedASC(begin,end):
    l = [[begin,0,inc(),0]]
    visited = []
    while l:
      current = l.pop(0)
      visited.append(current)
      dot.node(str(current[2]), str(current[0]),fillcolor='green',style='filled')
      if current[0]== end:
          dot.node(str(current[2]), str(current[0]),fillcolor='pink',style='filled',shape='doublecircle')
          print("Visited:"+str(len(visited))+" nodes \n")
          print("No visited:"+str(len(l))+" nodes \n")
          return print("Found:"+str(i)+" nodes")
      tmp =  succesor(current)
      if tmp:
              for x in tmp:
                  dot.node(str(x[2]), str(x[0]),fillcolor='yellow',style='filled')
                  dot.edge(str(current[2]), str(x[2]))
              l.extend(tmp)
    print("Not Found:"+str(i)+" nodes")




dot = Graph()
dot.attr(splines='false')
dot.node_attr.update(shape='circle',fontname='arial', color='blue4',fontcolor='blue4')
dot.edge_attr.update(color='blue4')

breadthlimitedASC('C3', 'A1')
#breadthlimitedASC('C2', 'A1')




dot.view()
dot.render('arbol_busqueda_limitado', format='png')
from IPython.display import Image

# Mostrar el gráfico en el cuaderno
Image('arbol_busqueda_limitado.png')
# Out:
# Visited:8 nodes
#
# No visited:1 nodes
#
# Found:9 nodes
