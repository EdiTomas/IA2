# %%
import numpy as np
from sklearn.manifold import MDS
#from matplotlib import pyplot as plt
from sklearn.preprocessing import PolynomialFeatures 
import matplotlib.pyplot as plt
#import numpy as np
import pandas as pd
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score





url = 'https://raw.githubusercontent.com/EdiTomas/Excel/master/Clientes.csv'
df = pd.read_csv(url)
#print(df)

# establecer los datos de entrenamiento
cliente = np.asarray(df['ID CLIENTE']).reshape(-1,1)
#y = df['pa']
#print(cliente)

X = np.array(cliente)


print(X[:-1])
# Out:
# [[1373166]
#  [4017736]
#  [4019659]
#  ...
#  [1542579]
#  [1501131]
#  [ 765525]]
