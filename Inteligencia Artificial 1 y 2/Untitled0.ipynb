# %%
from queue import PriorityQueue

def heuristica_casillas_fuera_de_lugar(estado_actual, estado_final):
    contador = 0
    for i in range(len(estado_actual)):
        if estado_actual[i] != estado_final[i]:
            contador += 1
    return contador

def resolver_puzzle_A_estrella(estado_inicial, estado_final):
    frontera = PriorityQueue()
    frontera.put((0, estado_inicial))  # Insertar el estado inicial con un costo g(n) de 0
    explorado = set()

    while not frontera.empty():
        costo_actual, estado_actual = frontera.get()
        if estado_actual == estado_final:
            return costo_actual

        explorado.add(estado_actual)

        for accion in acciones_posibles(estado_actual):
            nuevo_estado = aplicar_accion(estado_actual, accion)
            if nuevo_estado not in explorado:
                costo = costo_actual + 1
                prioridad = costo + heuristica_casillas_fuera_de_lugar(nuevo_estado, estado_final)
                frontera.put((prioridad, nuevo_estado))

    # Si se llega a este punto, no se encontró una solución
    return "No se encontró una solución"

# Funciones auxiliares
def acciones_posibles(estado):
    # Devuelve una lista de las acciones posibles en el estado actual
    acciones = []
    if 'A' in estado and 'B' in estado:
        acciones.append('AB')
    if 'B' in estado and 'C' in estado:
        acciones.append('BC')
    if 'C' in estado and 'D' in estado:
        acciones.append('CD')
    if 'D' in estado and 'A' in estado:
        acciones.append('DA')
    return acciones

def aplicar_accion(estado, accion):
    # Aplica la acción al estado actual y devuelve el nuevo estado
    nuevo_estado = list(estado)
    if accion == 'AB':
        nuevo_estado[nuevo_estado.index('A')] = 'B'
        nuevo_estado[nuevo_estado.index('B')] = 'A'
    elif accion == 'BC':
        nuevo_estado[nuevo_estado.index('B')] = 'C'
        nuevo_estado[nuevo_estado.index('C')] = 'B'
    elif accion == 'CD':
        nuevo_estado[nuevo_estado.index('C')] = 'D'
        nuevo_estado[nuevo_estado.index('D')] = 'C'
    elif accion == 'DA':
        nuevo_estado[nuevo_estado.index('D')] = 'A'
        nuevo_estado[nuevo_estado.index('A')] = 'D'
    return ''.join(nuevo_estado)

# Prueba del algoritmo
estado_inicial = "DCBA"
estado_final = "ABCD"
solucion = resolver_puzzle_A_estrella(estado_inicial, estado_final)
print(solucion)
# Out:
# 20

# %%
def heuristica_casillas_fuera_de_lugar(estado_actual, estado_final):
    contador = 0
    for i in range(len(estado_actual)):
        if estado_actual[i] != estado_final[i]:
            contador += 1
    return contador

def resolver_puzzle_A_estrella(estado_inicial, estado_final):
    frontera = PriorityQueue()
    frontera.put((0, estado_inicial))  # Insertar el estado inicial con un costo g(n) de 0
    explorado = set()

    iteraciones = 0
    max_f_x = float('-inf')  # Valor inicial para el máximo f(x)

    while not frontera.empty() and iteraciones < 5:
        costo_actual, estado_actual = frontera.get()
        f_x = costo_actual + heuristica_casillas_fuera_de_lugar(estado_actual, estado_final)
        if f_x > max_f_x:
            max_f_x = f_x

        if estado_actual == estado_final:
            return costo_actual

        explorado.add(estado_actual)

        for accion in acciones_posibles(estado_actual):
            nuevo_estado = aplicar_accion(estado_actual, accion)
            if nuevo_estado not in explorado:
                costo = costo_actual + 1
                prioridad = costo + heuristica_casillas_fuera_de_lugar(nuevo_estado, estado_final)
                frontera.put((prioridad, nuevo_estado))

        iteraciones += 1

    # Si se llega a este punto, no se encontró una solución
    return "No se encontró una solución"

# Funciones auxiliares
def acciones_posibles(estado):
    acciones = []
    if 'A' in estado and 'B' in estado:
        acciones.append('AB')
    if 'B' in estado and 'C' in estado:
        acciones.append('BC')
    if 'C' in estado and 'D' in estado:
        acciones.append('CD')
    if 'D' in estado and 'A' in estado:
        acciones.append('DA')
    return acciones

def aplicar_accion(estado, accion):
    nuevo_estado = list(estado)
    if accion == 'AB':
        nuevo_estado[nuevo_estado.index('A')] = 'B'
        nuevo_estado[nuevo_estado.index('B')] = 'A'
    elif accion == 'BC':
        nuevo_estado[nuevo_estado.index('B')] = 'C'
        nuevo_estado[nuevo_estado.index('C')] = 'B'
    elif accion == 'CD':
        nuevo_estado[nuevo_estado.index('C')] = 'D'
        nuevo_estado[nuevo_estado.index('D')] = 'C'
    elif accion == 'DA':
        nuevo_estado[nuevo_estado.index('D')] = 'A'
        nuevo_estado[nuevo_estado.index('A')] = 'D'
    return ''.join(nuevo_estado)

# Prueba del algoritmo
estado_inicial = "DCBA"
estado_final = "ABCD"
#solucion = resolver_puzzle_A
solucion = resolver_puzzle_A_estrella(estado_inicial, estado_final)
print(solucion)
# Out:
# No se encontró una solución

# %%
from queue import PriorityQueue

def heuristica_casillas_fuera_de_lugar(estado_actual, estado_final):
    contador = 0
    for i in range(len(estado_actual)):
        if estado_actual[i] != estado_final[i]:
            contador += 1
    return contador

def resolver_puzzle_A_estrella(estado_inicial, estado_final):
    frontera = PriorityQueue()
    frontera.put((0, estado_inicial))  # Insertar el estado inicial con un costo g(n) de 0
    explorado = set()
    nivel = 0

    while not frontera.empty():
        costo_actual, estado_actual = frontera.get()

        if estado_actual == estado_final:
            return nivel

        explorado.add(estado_actual)

        for accion in acciones_posibles(estado_actual):
            nuevo_estado = aplicar_accion(estado_actual, accion)
            if nuevo_estado not in explorado:
                costo = costo_actual + 1
                prioridad = costo + heuristica_casillas_fuera_de_lugar(nuevo_estado, estado_final)
                frontera.put((prioridad, nuevo_estado))

        nivel += 1

    # Si se llega a este punto, no se encontró una solución
    return "No se encontró una solución"

# Funciones auxiliares
def acciones_posibles(estado):
    acciones = []
    if 'A' in estado and 'B' in estado:
        acciones.append('AB')
    if 'B' in estado and 'C' in estado:
        acciones.append('BC')
    if 'C' in estado and 'D' in estado:
        acciones.append('CD')
    if 'D' in estado and 'A' in estado:
        acciones.append('DA')
    return acciones

def aplicar_accion(estado, accion):
    nuevo_estado = list(estado)
    if accion == 'AB':
        nuevo_estado[nuevo_estado.index('A')] = 'B'
        nuevo_estado[nuevo_estado.index('B')] = 'A'
    elif accion == 'BC':
        nuevo_estado[nuevo_estado.index('B')] = 'C'
        nuevo_estado[nuevo_estado.index('C')] = 'B'
    elif accion == 'CD':
        nuevo_estado[nuevo_estado.index('C')] = 'D'
        nuevo_estado[nuevo_estado.index('D')] = 'C'
    elif accion == 'DA':
        nuevo_estado[nuevo_estado.index('D')] = 'A'
        nuevo_estado[nuevo_estado.index('A')] = 'D'
    return ''.join(nuevo_estado)

# Prueba del algoritmo
estado_inicial = "DCBA"
estado_final = "ABCD"
nivel_solucion = resolver_puzzle_A_estrella(estado_inicial, estado_final)
print("La solución se encontró en el nivel:", nivel_solucion)
# Out:
# La solución se encontró en el nivel: 40

# %%
from queue import PriorityQueue

def heuristica_casillas_fuera_de_lugar(estado_actual, estado_final):
    contador = 0
    for i in range(len(estado_actual)):
        if estado_actual[i] != estado_final[i]:
            contador += 1
    return contador

def resolver_puzzle_A_estrella(estado_inicial, estado_final):
    frontera = PriorityQueue()
    frontera.put((0, estado_inicial))  # Insertar el estado inicial con un costo g(n) de 0
    explorado = set()
    iteracion = 0

    while not frontera.empty():
        costo_actual, estado_actual = frontera.get()

        if estado_actual == estado_final:
            return iteracion

        explorado.add(estado_actual)

        for accion in acciones_posibles(estado_actual):
            nuevo_estado = aplicar_accion(estado_actual, accion)
            if nuevo_estado not in explorado:
                costo = costo_actual + 1
                prioridad = costo + heuristica_casillas_fuera_de_lugar(nuevo_estado, estado_final)
                frontera.put((prioridad, nuevo_estado))

        iteracion += 1
        if iteracion == 10:
            return frontera.qsize()  # Cantidad de nodos en la lista en la iteración 10

    # Si se llega a este punto, no se encontró una solución
    return "No se encontró una solución"

# Funciones auxiliares
def acciones_posibles(estado):
    acciones = []
    if 'A' in estado and 'B' in estado:
        acciones.append('AB')
    if 'B' in estado and 'C' in estado:
        acciones.append('BC')
    if 'C' in estado and 'D' in estado:
        acciones.append('CD')
    if 'D' in estado and 'A' in estado:
        acciones.append('DA')
    return acciones

def aplicar_accion(estado, accion):
    nuevo_estado = list(estado)
    if accion == 'AB':
        nuevo_estado[nuevo_estado.index('A')] = 'B'
        nuevo_estado[nuevo_estado.index('B')] = 'A'
    elif accion == 'BC':
        nuevo_estado[nuevo_estado.index('B')] = 'C'
        nuevo_estado[nuevo_estado.index('C')] = 'B'
    elif accion == 'CD':
        nuevo_estado[nuevo_estado.index('C')] = 'D'
        nuevo_estado[nuevo_estado.index('D')] = 'C'
    elif accion == 'DA':
        nuevo_estado[nuevo_estado.index('D')] = 'A'
        nuevo_estado[nuevo_estado.index('A')] = 'D'
    return ''.join(nuevo_estado)

# Prueba del algoritmo
estado_inicial = "DCBA"
estado_final = "ABCD"
cantidad_nodos_iteracion_10 = resolver_puzzle_A_estrella(estado_inicial, estado_final)
print("Cantidad de nodos en la iteración 10:", cantidad_nodos_iteracion_10)
# Out:
# Cantidad de nodos en la iteración 10: 10

# %%
from queue import PriorityQueue

def heuristica_casillas_fuera_de_lugar(estado_actual, estado_final):
    contador = 0
    for i in range(len(estado_actual)):
        if estado_actual[i] != estado_final[i]:
            contador += 1
    return contador

def resolver_puzzle_A_estrella(estado_inicial, estado_final):
    frontera = PriorityQueue()
    frontera.put((0, estado_inicial))  # Insertar el estado inicial con un costo g(n) de 0
    explorado = set()
    visitados = 0

    while not frontera.empty():
        costo_actual, estado_actual = frontera.get()
        visitados += 1

        if estado_actual == estado_final:
            return visitados

        explorado.add(estado_actual)

        for accion in acciones_posibles(estado_actual):
            nuevo_estado = aplicar_accion(estado_actual, accion)
            if nuevo_estado not in explorado:
                costo = costo_actual + 1
                prioridad = costo + heuristica_casillas_fuera_de_lugar(nuevo_estado, estado_final)
                frontera.put((prioridad, nuevo_estado))

    # Si se llega a este punto, no se encontró una solución
    return "No se encontró una solución"

# Funciones auxiliares
def acciones_posibles(estado):
    acciones = []
    if 'A' in estado and 'B' in estado:
        acciones.append('AB')
    if 'B' in estado and 'C' in estado:
        acciones.append('BC')
    if 'C' in estado and 'D' in estado:
        acciones.append('CD')
    if 'D' in estado and 'A' in estado:
        acciones.append('DA')
    return acciones

def aplicar_accion(estado, accion):
    nuevo_estado = list(estado)
    if accion == 'AB':
        nuevo_estado[nuevo_estado.index('A')] = 'B'
        nuevo_estado[nuevo_estado.index('B')] = 'A'
    elif accion == 'BC':
        nuevo_estado[nuevo_estado.index('B')] = 'C'
        nuevo_estado[nuevo_estado.index('C')] = 'B'
    elif accion == 'CD':
        nuevo_estado[nuevo_estado.index('C')] = 'D'
        nuevo_estado[nuevo_estado.index('D')] = 'C'
    elif accion == 'DA':
        nuevo_estado[nuevo_estado.index('D')] = 'A'
        nuevo_estado[nuevo_estado.index('A')] = 'D'
    return ''.join(nuevo_estado)

# Prueba del algoritmo
estado_inicial = "DCBA"
estado_final = "ABCD"
nodos_visitados = resolver_puzzle_A_estrella(estado_inicial, estado_final)
print("Cantidad de nodos visitados:", nodos_visitados)
# Out:
# Cantidad de nodos visitados: 41

# %%
from queue import PriorityQueue

def heuristica_casillas_fuera_de_lugar(estado_actual, estado_final):
    contador = 0
    for i in range(len(estado_actual)):
        if estado_actual[i] != estado_final[i]:
            contador += 1
    return contador

def resolver_puzzle_A_estrella(estado_inicial, estado_final):
    frontera = PriorityQueue()
    frontera.put((0, estado_inicial))  # Insertar el estado inicial con un costo g(n) de 0
    explorado = set()
    iteracion = 0

    while not frontera.empty():
        costo_actual, estado_actual = frontera.get()

        if iteracion == 40:
            nivel = costo_actual
            f_valor = costo_actual + heuristica_casillas_fuera_de_lugar(estado_actual, estado_final)
            return f_valor, nivel

        explorado.add(estado_actual)

        for accion in acciones_posibles(estado_actual):
            nuevo_estado = aplicar_accion(estado_actual, accion)
            if nuevo_estado not in explorado:
                costo = costo_actual + 1
                prioridad = costo + heuristica_casillas_fuera_de_lugar(nuevo_estado, estado_final)
                frontera.put((prioridad, nuevo_estado))

        iteracion += 1

    # Si se llega a este punto, no se encontró una solución en la iteración 40
    return "No se encontró una solución en la iteración 40"

# Funciones auxiliares
def acciones_posibles(estado):
    acciones = []
    if 'A' in estado and 'B' in estado:
        acciones.append('AB')
    if 'B' in estado and 'C' in estado:
        acciones.append('BC')
    if 'C' in estado and 'D' in estado:
        acciones.append('CD')
    if 'D' in estado and 'A' in estado:
        acciones.append('DA')
    return acciones

def aplicar_accion(estado, accion):
    nuevo_estado = list(estado)
    if accion == 'AB':
        nuevo_estado[nuevo_estado.index('A')] = 'B'
        nuevo_estado[nuevo_estado.index('B')] = 'A'
    elif accion == 'BC':
        nuevo_estado[nuevo_estado.index('B')] = 'C'
        nuevo_estado[nuevo_estado.index('C')] = 'B'
    elif accion == 'CD':
        nuevo_estado[nuevo_estado.index('C')] = 'D'
        nuevo_estado[nuevo_estado.index('D')] = 'C'
    elif accion == 'DA':
        nuevo_estado[nuevo_estado.index('D')] = 'A'
        nuevo_estado[nuevo_estado.index('A')] = 'D'
    return ''.join(nuevo_estado)

# Prueba del algoritmo
estado_inicial = "DCBA"
estado_final = "ABCD"
f_valor, nivel = resolver_puzzle_A_estrella(estado_inicial, estado_final)
print("Valor de f(x) en la iteración 40:", f_valor)
print("Nivel del nodo extraído en la iteración 40:", nivel)
# Out:
# Valor de f(x) en la iteración 40: 20
# Nivel del nodo extraído en la iteración 40: 20
